# %%
# Only display tensorflow errors
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from keras import Model
from keras.layers import Input, Dense, Dropout, BatchNormalization, Conv1D, MaxPooling1D, LSTM
from keras.losses import MeanSquaredError as MSE, MeanAbsoluteError as MAE, Huber
from keras.metrics import MeanAbsoluteError, MeanSquaredError
from tcn import TCN
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# 2025-03-26 07:45:11.306009: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742967911.316457 4177359 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742967911.319630 4177359 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742967911.328873 4177359 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742967911.328880 4177359 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742967911.328882 4177359 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742967911.328883 4177359 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
df = pd.read_csv('data/comp-merged.csv')
df = df[['value_acc', 'value_met']]
scaler = MinMaxScaler()
df['value_met'] = scaler.fit_transform(df['value_met'].values.reshape(-1, 1))
df['value_acc'] = scaler.transform(df['value_acc'].values.reshape(-1, 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['value_met'], label='Meteostat')
plt.plot(df['value_acc'], label='GPM-IMERG v7')
plt.title('IMERG vs Meteostat')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
batch_size = 1024
epochs = 1000
window_size = 32

# %%
def windowed_dataset(data, window_size, batch_size, shift=1, shuffle=True):
    """
    Create a windowed dataset from the input data.

    Parameters:
    data (np.array): The input data array.
    window_size (int): The size of each window.
    batch_size (int): The size of each batch.

    Returns:
    tf.data.Dataset: The windowed dataset.
    """
    dataset = tf.data.Dataset.from_tensor_slices(data)
    dataset = dataset.window(window_size, shift=shift, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size))
    dataset = dataset.map(lambda window: (tf.expand_dims(window[:, 0], axis=-1), tf.expand_dims(window[:, 1], axis=-1)))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)
    
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
def windowed_dataset_single(data, window_size, batch_size):
    """
    Create a windowed dataset from the input data.

    Parameters:
    data (np.array): The input data array.
    window_size (int): The size of each window.
    batch_size (int): The size of each batch.

    Returns:
    tf.data.Dataset: The windowed dataset.
    """
    dataset = tf.data.Dataset.from_tensor_slices(data)
    dataset = dataset.window(window_size, shift=window_size, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size))
    dataset = dataset.map(lambda window: tf.expand_dims(window, axis=-1))
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
# Split the dataframe into train and test sets
train, test = train_test_split(df, test_size=0.05, shuffle=False)

train_set = windowed_dataset(train, window_size, batch_size, shift=1, shuffle=True)
test_set = windowed_dataset(test, window_size, batch_size, shift=window_size, shuffle=False)
# Out:
# I0000 00:00:1742967917.447679 4177359 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22238 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:08:00.0, compute capability: 8.6

# %%
data = windowed_dataset(df, window_size, batch_size, shuffle=False)
actuals = [y for x, y in data]
print(actuals[0].shape)
actuals = np.concatenate(actuals, axis=0).flatten()

print(actuals.shape)
print(df['value_met'].shape)

plt.figure(figsize=(10, 6))
plt.plot(actuals)
plt.plot(df['value_met'])
plt.title('Actuals vs Meteo')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# (1024, 32, 1)
# (564672,)
# (17677,)
# /tmp/ipykernel_4177359/4153096080.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
class RootMeanSqauredError(MeanSquaredError):
    def update_state(self, y_true, y_pred, sample_weight=None):
        return super().update_state(y_true, y_pred, sample_weight)

    def result(self):
        return tf.sqrt(super().result())

# %%
def build_model():
    """
    Build a CONV-LSTM model for error correction.
    
    Returns:
    keras.Model: The compiled model
    """
    # Input layer
    inputs = Input(shape=(window_size, 1))
    
    # # Encoder: progressively extract features with additional regularization
    x = TCN(
        nb_filters=256,
        return_sequences=True,
        dilations=[1, 2, 4, 8],
        use_layer_norm=True,
        use_skip_connections=True,
        dropout_rate=0.15
    )(inputs)
    x = BatchNormalization()(x)
    
    # Bottleneck layer with stronger regularization
    bottleneck = Dense(
        64, 
        activation=None,
        kernel_regularizer=keras.regularizers.l2(1e-4)
    )(x)
    bottleneck = Dropout(0.15)(bottleneck)
    
    # Decoder with additional regularization
    x = TCN(
        nb_filters=256,
        return_sequences=True,
        dilations=[1, 2, 4, 8],
        use_layer_norm=True,
        dropout_rate=0.15
    )(x)
    x = BatchNormalization()(x)
    # x = Dense(
    #     16, 
    #     activation='relu',
    #     kernel_regularizer=keras.regularizers.l2(1e-4)
    # )(x)
    # x = Dense(
    #     8,
    #     activation='relu',
    #     kernel_regularizer=keras.regularizers.l2(1e-4)
    # )(x)
    # Output layer with L2 regularization
    # x = LSTM(
    #     units=32,
    #     return_sequences=True,
    #     kernel_regularizer=keras.regularizers.l2(1e-4),
    #     recurrent_regularizer=keras.regularizers.l2(1.2e-4)
    # )(inputs)
    # x = Dense(
    #     16,
    #     activation=None,
    #     kernel_regularizer=keras.regularizers.l2(1e-4)
    # )(x)
    # x = LSTM(
    #     units=32, 
    #     return_sequences=True,
    #     kernel_regularizer=keras.regularizers.l2(1e-4),
    #     recurrent_regularizer=keras.regularizers.l2(1.2e-4)
    # )(x)
    outputs = Dense(
        1
    )(x)
    
    # Modified learning rate schedule with lower initial rate
    lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=1e-3,  # Lower initial learning rate
        decay_steps=1000,            # More frequent decay
        decay_rate=0.9              # More aggressive decay
    )

    # Create and compile model with Huber loss
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr_scheduler),  # Adam instead of Nadam
        loss=MSE(),  # Huber loss is more robust than MAE
        metrics=[
            MeanSquaredError(name='mse'),
            MeanAbsoluteError(name='mae'),
            RootMeanSqauredError(name='rmse')
        ]
    )
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tcn_2 (TCN)                     │ (None, 32, 256)        │       924,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tcn_3 (TCN)                     │ (None, 32, 256)        │     1,054,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32, 1)          │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,981,697 (7.56 MB)
#  Trainable params: 1,980,673 (7.56 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
history = model.fit(
  train_set,
  epochs=epochs,
  validation_data=test_set,
  verbose=1,
#   callbacks=[keras.callbacks.EarlyStopping(patience=10, monitor='val_rmse', min_delta=1e-6)]
)
# Out:
# Epoch 1/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 549ms/step - loss: 2.3066 - mae: 1.0840 - mse: 2.3066 - rmse: 1.5054 - val_loss: 3.0762 - val_mae: 1.6911 - val_mse: 3.0762 - val_rmse: 1.7539
# Epoch 2/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4468 - mae: 0.5299 - mse: 0.4468 - rmse: 0.6678 - val_loss: 0.4280 - val_mae: 0.5975 - val_mse: 0.4280 - val_rmse: 0.6542
# Epoch 3/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2701 - mae: 0.4118 - mse: 0.2701 - rmse: 0.5196 - val_loss: 0.9766 - val_mae: 0.9542 - val_mse: 0.9766 - val_rmse: 0.9882
# Epoch 4/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.1798 - mae: 0.3361 - mse: 0.1798 - rmse: 0.4239 - val_loss: 0.4515 - val_mae: 0.6424 - val_mse: 0.4515 - val_rmse: 0.6720
# Epoch 5/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1367 - mae: 0.2930 - mse: 0.1367 - rmse: 0.3698 - val_loss: 0.2818 - val_mae: 0.5016 - val_mse: 0.2818 - val_rmse: 0.5308
# Epoch 6/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1086 - mae: 0.2607 - mse: 0.1086 - rmse: 0.3295 - val_loss: 0.1366 - val_mae: 0.3335 - val_mse: 0.1366 - val_rmse: 0.3696
# Epoch 7/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0909 - mae: 0.2382 - mse: 0.0909 - rmse: 0.3014 - val_loss: 0.0582 - val_mae: 0.2023 - val_mse: 0.0582 - val_rmse: 0.2412
# Epoch 8/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0762 - mae: 0.2181 - mse: 0.0762 - rmse: 0.2760 - val_loss: 0.0166 - val_mae: 0.0966 - val_mse: 0.0166 - val_rmse: 0.1289
# Epoch 9/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0622 - mae: 0.1965 - mse: 0.0622 - rmse: 0.2493 - val_loss: 0.0070 - val_mae: 0.0546 - val_mse: 0.0070 - val_rmse: 0.0839
# Epoch 10/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0494 - mae: 0.1756 - mse: 0.0494 - rmse: 0.2222 - val_loss: 0.0152 - val_mae: 0.1043 - val_mse: 0.0152 - val_rmse: 0.1233
# Epoch 11/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0423 - mae: 0.1624 - mse: 0.0423 - rmse: 0.2057 - val_loss: 0.0301 - val_mae: 0.1639 - val_mse: 0.0301 - val_rmse: 0.1736
# Epoch 12/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0364 - mae: 0.1501 - mse: 0.0364 - rmse: 0.1907 - val_loss: 0.0556 - val_mae: 0.2223 - val_mse: 0.0556 - val_rmse: 0.2358
# Epoch 13/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0319 - mae: 0.1408 - mse: 0.0319 - rmse: 0.1787 - val_loss: 0.0478 - val_mae: 0.2085 - val_mse: 0.0478 - val_rmse: 0.2186
# Epoch 14/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0280 - mae: 0.1321 - mse: 0.0280 - rmse: 0.1673 - val_loss: 0.0620 - val_mae: 0.2393 - val_mse: 0.0620 - val_rmse: 0.2490
# Epoch 15/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0258 - mae: 0.1263 - mse: 0.0258 - rmse: 0.1606 - val_loss: 0.0583 - val_mae: 0.2301 - val_mse: 0.0583 - val_rmse: 0.2414
# Epoch 16/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0229 - mae: 0.1187 - mse: 0.0229 - rmse: 0.1513 - val_loss: 0.0467 - val_mae: 0.2089 - val_mse: 0.0467 - val_rmse: 0.2162
# Epoch 17/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0213 - mae: 0.1148 - mse: 0.0213 - rmse: 0.1460 - val_loss: 0.0613 - val_mae: 0.2300 - val_mse: 0.0613 - val_rmse: 0.2476
# Epoch 18/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0198 - mae: 0.1105 - mse: 0.0198 - rmse: 0.1406 - val_loss: 0.0630 - val_mae: 0.2403 - val_mse: 0.0630 - val_rmse: 0.2510
# Epoch 19/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0185 - mae: 0.1068 - mse: 0.0185 - rmse: 0.1360 - val_loss: 0.0419 - val_mae: 0.1906 - val_mse: 0.0419 - val_rmse: 0.2046
# Epoch 20/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0175 - mae: 0.1036 - mse: 0.0175 - rmse: 0.1321 - val_loss: 0.0528 - val_mae: 0.2060 - val_mse: 0.0528 - val_rmse: 0.2299
# Epoch 21/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0181 - mae: 0.1062 - mse: 0.0181 - rmse: 0.1346 - val_loss: 0.0361 - val_mae: 0.1710 - val_mse: 0.0361 - val_rmse: 0.1899
# Epoch 22/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0211 - mae: 0.1144 - mse: 0.0211 - rmse: 0.1448 - val_loss: 0.0183 - val_mae: 0.1231 - val_mse: 0.0183 - val_rmse: 0.1353
# Epoch 23/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0452 - mae: 0.1670 - mse: 0.0452 - rmse: 0.2106 - val_loss: 0.1196 - val_mae: 0.3175 - val_mse: 0.1196 - val_rmse: 0.3459
# Epoch 24/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0948 - mae: 0.2432 - mse: 0.0948 - rmse: 0.3069 - val_loss: 0.0339 - val_mae: 0.1678 - val_mse: 0.0339 - val_rmse: 0.1841
# Epoch 25/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0298 - mae: 0.1347 - mse: 0.0298 - rmse: 0.1722 - val_loss: 0.0073 - val_mae: 0.0649 - val_mse: 0.0073 - val_rmse: 0.0856
# Epoch 26/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0150 - mae: 0.0956 - mse: 0.0150 - rmse: 0.1223 - val_loss: 0.0083 - val_mae: 0.0574 - val_mse: 0.0083 - val_rmse: 0.0912
# Epoch 27/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0118 - mae: 0.0840 - mse: 0.0118 - rmse: 0.1085 - val_loss: 0.0075 - val_mae: 0.0648 - val_mse: 0.0075 - val_rmse: 0.0866
# Epoch 28/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0108 - mae: 0.0806 - mse: 0.0108 - rmse: 0.1039 - val_loss: 0.0095 - val_mae: 0.0769 - val_mse: 0.0095 - val_rmse: 0.0973
# Epoch 29/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0102 - mae: 0.0779 - mse: 0.0102 - rmse: 0.1011 - val_loss: 0.0111 - val_mae: 0.0926 - val_mse: 0.0111 - val_rmse: 0.1055
# Epoch 30/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0097 - mae: 0.0758 - mse: 0.0097 - rmse: 0.0984 - val_loss: 0.0092 - val_mae: 0.0823 - val_mse: 0.0092 - val_rmse: 0.0960
# Epoch 31/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0093 - mae: 0.0741 - mse: 0.0093 - rmse: 0.0964 - val_loss: 0.0104 - val_mae: 0.0856 - val_mse: 0.0104 - val_rmse: 0.1021
# Epoch 32/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0090 - mae: 0.0729 - mse: 0.0090 - rmse: 0.0946 - val_loss: 0.0110 - val_mae: 0.0893 - val_mse: 0.0110 - val_rmse: 0.1051
# Epoch 33/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0090 - mae: 0.0727 - mse: 0.0090 - rmse: 0.0947 - val_loss: 0.0094 - val_mae: 0.0831 - val_mse: 0.0094 - val_rmse: 0.0969
# Epoch 34/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0083 - mae: 0.0696 - mse: 0.0083 - rmse: 0.0908 - val_loss: 0.0098 - val_mae: 0.0867 - val_mse: 0.0098 - val_rmse: 0.0991
# Epoch 35/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0081 - mae: 0.0691 - mse: 0.0081 - rmse: 0.0902 - val_loss: 0.0100 - val_mae: 0.0873 - val_mse: 0.0100 - val_rmse: 0.0998
# Epoch 36/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0078 - mae: 0.0675 - mse: 0.0078 - rmse: 0.0884 - val_loss: 0.0093 - val_mae: 0.0790 - val_mse: 0.0093 - val_rmse: 0.0962
# Epoch 37/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0077 - mae: 0.0667 - mse: 0.0077 - rmse: 0.0875 - val_loss: 0.0089 - val_mae: 0.0786 - val_mse: 0.0089 - val_rmse: 0.0943
# Epoch 38/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0075 - mae: 0.0659 - mse: 0.0075 - rmse: 0.0866 - val_loss: 0.0090 - val_mae: 0.0772 - val_mse: 0.0090 - val_rmse: 0.0948
# Epoch 39/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0072 - mae: 0.0643 - mse: 0.0072 - rmse: 0.0847 - val_loss: 0.0075 - val_mae: 0.0719 - val_mse: 0.0075 - val_rmse: 0.0868
# Epoch 40/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0070 - mae: 0.0635 - mse: 0.0070 - rmse: 0.0836 - val_loss: 0.0071 - val_mae: 0.0682 - val_mse: 0.0071 - val_rmse: 0.0840
# Epoch 41/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0069 - mae: 0.0631 - mse: 0.0069 - rmse: 0.0830 - val_loss: 0.0072 - val_mae: 0.0672 - val_mse: 0.0072 - val_rmse: 0.0847
# Epoch 42/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0066 - mae: 0.0614 - mse: 0.0066 - rmse: 0.0810 - val_loss: 0.0066 - val_mae: 0.0639 - val_mse: 0.0066 - val_rmse: 0.0813
# Epoch 43/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0066 - mae: 0.0613 - mse: 0.0066 - rmse: 0.0809 - val_loss: 0.0071 - val_mae: 0.0692 - val_mse: 0.0071 - val_rmse: 0.0845
# Epoch 44/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0063 - mae: 0.0602 - mse: 0.0063 - rmse: 0.0796 - val_loss: 0.0074 - val_mae: 0.0678 - val_mse: 0.0074 - val_rmse: 0.0861
# Epoch 45/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0063 - mae: 0.0598 - mse: 0.0063 - rmse: 0.0792 - val_loss: 0.0066 - val_mae: 0.0624 - val_mse: 0.0066 - val_rmse: 0.0813
# Epoch 46/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0061 - mae: 0.0589 - mse: 0.0061 - rmse: 0.0781 - val_loss: 0.0067 - val_mae: 0.0647 - val_mse: 0.0067 - val_rmse: 0.0817
# Epoch 47/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0061 - mae: 0.0588 - mse: 0.0061 - rmse: 0.0778 - val_loss: 0.0060 - val_mae: 0.0588 - val_mse: 0.0060 - val_rmse: 0.0774
# Epoch 48/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0058 - mae: 0.0571 - mse: 0.0058 - rmse: 0.0760 - val_loss: 0.0063 - val_mae: 0.0613 - val_mse: 0.0063 - val_rmse: 0.0792
# Epoch 49/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0057 - mae: 0.0567 - mse: 0.0057 - rmse: 0.0752 - val_loss: 0.0069 - val_mae: 0.0664 - val_mse: 0.0069 - val_rmse: 0.0831
# Epoch 50/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0056 - mae: 0.0559 - mse: 0.0056 - rmse: 0.0747 - val_loss: 0.0054 - val_mae: 0.0513 - val_mse: 0.0054 - val_rmse: 0.0736
# Epoch 51/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0054 - mae: 0.0548 - mse: 0.0054 - rmse: 0.0732 - val_loss: 0.0059 - val_mae: 0.0575 - val_mse: 0.0059 - val_rmse: 0.0765
# Epoch 52/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0055 - mae: 0.0554 - mse: 0.0055 - rmse: 0.0739 - val_loss: 0.0053 - val_mae: 0.0481 - val_mse: 0.0053 - val_rmse: 0.0731
# Epoch 53/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0053 - mae: 0.0541 - mse: 0.0053 - rmse: 0.0723 - val_loss: 0.0060 - val_mae: 0.0562 - val_mse: 0.0060 - val_rmse: 0.0775
# Epoch 54/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0054 - mae: 0.0552 - mse: 0.0054 - rmse: 0.0737 - val_loss: 0.0059 - val_mae: 0.0578 - val_mse: 0.0059 - val_rmse: 0.0765
# Epoch 55/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0055 - mae: 0.0559 - mse: 0.0055 - rmse: 0.0741 - val_loss: 0.0067 - val_mae: 0.0648 - val_mse: 0.0067 - val_rmse: 0.0817
# Epoch 56/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0054 - mae: 0.0551 - mse: 0.0054 - rmse: 0.0736 - val_loss: 0.0057 - val_mae: 0.0452 - val_mse: 0.0057 - val_rmse: 0.0757
# Epoch 57/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0057 - mae: 0.0569 - mse: 0.0057 - rmse: 0.0754 - val_loss: 0.0065 - val_mae: 0.0461 - val_mse: 0.0065 - val_rmse: 0.0807
# Epoch 58/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0059 - mae: 0.0579 - mse: 0.0059 - rmse: 0.0767 - val_loss: 0.0064 - val_mae: 0.0467 - val_mse: 0.0064 - val_rmse: 0.0801
# Epoch 59/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0058 - mae: 0.0575 - mse: 0.0058 - rmse: 0.0763 - val_loss: 0.0076 - val_mae: 0.0528 - val_mse: 0.0076 - val_rmse: 0.0871
# Epoch 60/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0059 - mae: 0.0576 - mse: 0.0059 - rmse: 0.0765 - val_loss: 0.0082 - val_mae: 0.0578 - val_mse: 0.0082 - val_rmse: 0.0907
# Epoch 61/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0055 - mae: 0.0556 - mse: 0.0055 - rmse: 0.0741 - val_loss: 0.0075 - val_mae: 0.0548 - val_mse: 0.0075 - val_rmse: 0.0868
# Epoch 62/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0524 - mse: 0.0050 - rmse: 0.0706 - val_loss: 0.0082 - val_mae: 0.0591 - val_mse: 0.0082 - val_rmse: 0.0904
# Epoch 63/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0525 - mse: 0.0050 - rmse: 0.0708 - val_loss: 0.0062 - val_mae: 0.0453 - val_mse: 0.0062 - val_rmse: 0.0789
# Epoch 64/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0046 - mae: 0.0501 - mse: 0.0046 - rmse: 0.0680 - val_loss: 0.0057 - val_mae: 0.0413 - val_mse: 0.0057 - val_rmse: 0.0754
# Epoch 65/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0044 - mae: 0.0485 - mse: 0.0044 - rmse: 0.0661 - val_loss: 0.0044 - val_mae: 0.0352 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 66/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0042 - mae: 0.0472 - mse: 0.0042 - rmse: 0.0646 - val_loss: 0.0048 - val_mae: 0.0372 - val_mse: 0.0048 - val_rmse: 0.0691
# Epoch 67/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0042 - mae: 0.0470 - mse: 0.0042 - rmse: 0.0645 - val_loss: 0.0049 - val_mae: 0.0416 - val_mse: 0.0049 - val_rmse: 0.0701
# Epoch 68/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - mae: 0.0467 - mse: 0.0041 - rmse: 0.0641 - val_loss: 0.0050 - val_mae: 0.0428 - val_mse: 0.0050 - val_rmse: 0.0708
# Epoch 69/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - mae: 0.0463 - mse: 0.0041 - rmse: 0.0637 - val_loss: 0.0051 - val_mae: 0.0453 - val_mse: 0.0051 - val_rmse: 0.0712
# Epoch 70/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041 - rmse: 0.0637 - val_loss: 0.0054 - val_mae: 0.0374 - val_mse: 0.0054 - val_rmse: 0.0734
# Epoch 71/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - mae: 0.0469 - mse: 0.0041 - rmse: 0.0641 - val_loss: 0.0056 - val_mae: 0.0508 - val_mse: 0.0056 - val_rmse: 0.0746
# Epoch 72/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0039 - mae: 0.0450 - mse: 0.0039 - rmse: 0.0622 - val_loss: 0.0065 - val_mae: 0.0486 - val_mse: 0.0065 - val_rmse: 0.0806
# Epoch 73/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0042 - mae: 0.0471 - mse: 0.0042 - rmse: 0.0646 - val_loss: 0.0053 - val_mae: 0.0367 - val_mse: 0.0053 - val_rmse: 0.0728
# Epoch 74/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0040 - mae: 0.0456 - mse: 0.0040 - rmse: 0.0630 - val_loss: 0.0049 - val_mae: 0.0440 - val_mse: 0.0049 - val_rmse: 0.0703
# Epoch 75/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0038 - mae: 0.0442 - mse: 0.0038 - rmse: 0.0613 - val_loss: 0.0053 - val_mae: 0.0515 - val_mse: 0.0053 - val_rmse: 0.0729
# Epoch 76/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0038 - mae: 0.0442 - mse: 0.0038 - rmse: 0.0614 - val_loss: 0.0053 - val_mae: 0.0393 - val_mse: 0.0053 - val_rmse: 0.0727
# Epoch 77/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0038 - mae: 0.0440 - mse: 0.0038 - rmse: 0.0612 - val_loss: 0.0049 - val_mae: 0.0427 - val_mse: 0.0049 - val_rmse: 0.0699
# Epoch 78/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036 - rmse: 0.0601 - val_loss: 0.0051 - val_mae: 0.0361 - val_mse: 0.0051 - val_rmse: 0.0711
# Epoch 79/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0038 - mae: 0.0444 - mse: 0.0038 - rmse: 0.0617 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0066 - val_rmse: 0.0815
# Epoch 80/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0037 - mae: 0.0433 - mse: 0.0037 - rmse: 0.0605 - val_loss: 0.0046 - val_mae: 0.0409 - val_mse: 0.0046 - val_rmse: 0.0677
# Epoch 81/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0036 - mae: 0.0431 - mse: 0.0036 - rmse: 0.0600 - val_loss: 0.0051 - val_mae: 0.0491 - val_mse: 0.0051 - val_rmse: 0.0715
# Epoch 82/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0039 - mae: 0.0448 - mse: 0.0039 - rmse: 0.0619 - val_loss: 0.0049 - val_mae: 0.0404 - val_mse: 0.0049 - val_rmse: 0.0701
# Epoch 83/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0034 - mae: 0.0416 - mse: 0.0034 - rmse: 0.0583 - val_loss: 0.0048 - val_mae: 0.0394 - val_mse: 0.0048 - val_rmse: 0.0689
# Epoch 84/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0036 - mae: 0.0424 - mse: 0.0036 - rmse: 0.0595 - val_loss: 0.0050 - val_mae: 0.0432 - val_mse: 0.0050 - val_rmse: 0.0704
# Epoch 85/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0035 - mae: 0.0422 - mse: 0.0035 - rmse: 0.0590 - val_loss: 0.0058 - val_mae: 0.0422 - val_mse: 0.0058 - val_rmse: 0.0761
# Epoch 86/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0038 - mae: 0.0441 - mse: 0.0038 - rmse: 0.0611 - val_loss: 0.0058 - val_mae: 0.0404 - val_mse: 0.0058 - val_rmse: 0.0764
# Epoch 87/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0040 - mae: 0.0455 - mse: 0.0040 - rmse: 0.0632 - val_loss: 0.0051 - val_mae: 0.0357 - val_mse: 0.0051 - val_rmse: 0.0714
# Epoch 88/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0047 - mae: 0.0499 - mse: 0.0047 - rmse: 0.0682 - val_loss: 0.0056 - val_mae: 0.0418 - val_mse: 0.0056 - val_rmse: 0.0748
# Epoch 89/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0067 - mae: 0.0607 - mse: 0.0067 - rmse: 0.0809 - val_loss: 0.0044 - val_mae: 0.0328 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 90/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0111 - mae: 0.0803 - mse: 0.0111 - rmse: 0.1042 - val_loss: 0.0130 - val_mae: 0.1012 - val_mse: 0.0130 - val_rmse: 0.1142
# Epoch 91/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0202 - mae: 0.1115 - mse: 0.0202 - rmse: 0.1415 - val_loss: 0.0475 - val_mae: 0.2076 - val_mse: 0.0475 - val_rmse: 0.2178
# Epoch 92/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0236 - mae: 0.1219 - mse: 0.0236 - rmse: 0.1528 - val_loss: 0.0225 - val_mae: 0.1378 - val_mse: 0.0225 - val_rmse: 0.1499
# Epoch 93/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0088 - mae: 0.0738 - mse: 0.0088 - rmse: 0.0936 - val_loss: 0.0051 - val_mae: 0.0366 - val_mse: 0.0051 - val_rmse: 0.0713
# Epoch 94/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0048 - mae: 0.0504 - mse: 0.0048 - rmse: 0.0689 - val_loss: 0.0042 - val_mae: 0.0288 - val_mse: 0.0042 - val_rmse: 0.0647
# Epoch 95/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0035 - mae: 0.0416 - mse: 0.0035 - rmse: 0.0589 - val_loss: 0.0043 - val_mae: 0.0329 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 96/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0032 - mae: 0.0397 - mse: 0.0032 - rmse: 0.0564 - val_loss: 0.0043 - val_mae: 0.0353 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 97/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0031 - mae: 0.0384 - mse: 0.0031 - rmse: 0.0550 - val_loss: 0.0047 - val_mae: 0.0428 - val_mse: 0.0047 - val_rmse: 0.0688
# Epoch 98/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0031 - mae: 0.0386 - mse: 0.0031 - rmse: 0.0551 - val_loss: 0.0049 - val_mae: 0.0467 - val_mse: 0.0049 - val_rmse: 0.0702
# Epoch 99/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0030 - mae: 0.0377 - mse: 0.0030 - rmse: 0.0541 - val_loss: 0.0050 - val_mae: 0.0469 - val_mse: 0.0050 - val_rmse: 0.0704
# Epoch 100/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0029 - mae: 0.0376 - mse: 0.0029 - rmse: 0.0539 - val_loss: 0.0046 - val_mae: 0.0420 - val_mse: 0.0046 - val_rmse: 0.0680
# Epoch 101/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0029 - mae: 0.0373 - mse: 0.0029 - rmse: 0.0536 - val_loss: 0.0051 - val_mae: 0.0442 - val_mse: 0.0051 - val_rmse: 0.0712
# Epoch 102/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0030 - mae: 0.0380 - mse: 0.0030 - rmse: 0.0545 - val_loss: 0.0045 - val_mae: 0.0369 - val_mse: 0.0045 - val_rmse: 0.0669
# Epoch 103/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0030 - mae: 0.0377 - mse: 0.0030 - rmse: 0.0543 - val_loss: 0.0049 - val_mae: 0.0464 - val_mse: 0.0049 - val_rmse: 0.0700
# Epoch 104/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0367 - mse: 0.0028 - rmse: 0.0530 - val_loss: 0.0050 - val_mae: 0.0481 - val_mse: 0.0050 - val_rmse: 0.0708
# Epoch 105/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0363 - mse: 0.0028 - rmse: 0.0526 - val_loss: 0.0045 - val_mae: 0.0396 - val_mse: 0.0045 - val_rmse: 0.0671
# Epoch 106/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0361 - mse: 0.0028 - rmse: 0.0527 - val_loss: 0.0047 - val_mae: 0.0422 - val_mse: 0.0047 - val_rmse: 0.0687
# Epoch 107/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0360 - mse: 0.0028 - rmse: 0.0524 - val_loss: 0.0052 - val_mae: 0.0481 - val_mse: 0.0052 - val_rmse: 0.0718
# Epoch 108/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0360 - mse: 0.0028 - rmse: 0.0524 - val_loss: 0.0055 - val_mae: 0.0546 - val_mse: 0.0055 - val_rmse: 0.0744
# Epoch 109/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0351 - mse: 0.0027 - rmse: 0.0514 - val_loss: 0.0054 - val_mae: 0.0522 - val_mse: 0.0054 - val_rmse: 0.0734
# Epoch 110/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0360 - mse: 0.0028 - rmse: 0.0522 - val_loss: 0.0051 - val_mae: 0.0487 - val_mse: 0.0051 - val_rmse: 0.0715
# Epoch 111/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0350 - mse: 0.0027 - rmse: 0.0512 - val_loss: 0.0054 - val_mae: 0.0517 - val_mse: 0.0054 - val_rmse: 0.0731
# Epoch 112/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0350 - mse: 0.0027 - rmse: 0.0514 - val_loss: 0.0047 - val_mae: 0.0435 - val_mse: 0.0047 - val_rmse: 0.0684
# Epoch 113/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0351 - mse: 0.0027 - rmse: 0.0515 - val_loss: 0.0050 - val_mae: 0.0475 - val_mse: 0.0050 - val_rmse: 0.0708
# Epoch 114/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0347 - mse: 0.0026 - rmse: 0.0511 - val_loss: 0.0059 - val_mae: 0.0557 - val_mse: 0.0059 - val_rmse: 0.0765
# Epoch 115/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0352 - mse: 0.0027 - rmse: 0.0513 - val_loss: 0.0052 - val_mae: 0.0504 - val_mse: 0.0052 - val_rmse: 0.0724
# Epoch 116/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0344 - mse: 0.0026 - rmse: 0.0506 - val_loss: 0.0047 - val_mae: 0.0429 - val_mse: 0.0047 - val_rmse: 0.0687
# Epoch 117/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0347 - mse: 0.0026 - rmse: 0.0511 - val_loss: 0.0053 - val_mae: 0.0508 - val_mse: 0.0053 - val_rmse: 0.0725
# Epoch 118/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0342 - mse: 0.0026 - rmse: 0.0502 - val_loss: 0.0045 - val_mae: 0.0396 - val_mse: 0.0045 - val_rmse: 0.0672
# Epoch 119/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0336 - mse: 0.0025 - rmse: 0.0498 - val_loss: 0.0048 - val_mae: 0.0451 - val_mse: 0.0048 - val_rmse: 0.0696
# Epoch 120/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0336 - mse: 0.0025 - rmse: 0.0499 - val_loss: 0.0047 - val_mae: 0.0418 - val_mse: 0.0047 - val_rmse: 0.0682
# Epoch 121/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0333 - mse: 0.0025 - rmse: 0.0496 - val_loss: 0.0048 - val_mae: 0.0438 - val_mse: 0.0048 - val_rmse: 0.0689
# Epoch 122/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0336 - mse: 0.0025 - rmse: 0.0498 - val_loss: 0.0047 - val_mae: 0.0432 - val_mse: 0.0047 - val_rmse: 0.0687
# Epoch 123/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0331 - mse: 0.0025 - rmse: 0.0492 - val_loss: 0.0050 - val_mae: 0.0478 - val_mse: 0.0050 - val_rmse: 0.0710
# Epoch 124/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0330 - mse: 0.0025 - rmse: 0.0492 - val_loss: 0.0044 - val_mae: 0.0319 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 125/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0332 - mse: 0.0025 - rmse: 0.0497 - val_loss: 0.0047 - val_mae: 0.0395 - val_mse: 0.0047 - val_rmse: 0.0684
# Epoch 126/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0331 - mse: 0.0025 - rmse: 0.0495 - val_loss: 0.0048 - val_mae: 0.0431 - val_mse: 0.0048 - val_rmse: 0.0694
# Epoch 127/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0325 - mse: 0.0024 - rmse: 0.0488 - val_loss: 0.0047 - val_mae: 0.0396 - val_mse: 0.0047 - val_rmse: 0.0682
# Epoch 128/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0323 - mse: 0.0024 - rmse: 0.0486 - val_loss: 0.0045 - val_mae: 0.0383 - val_mse: 0.0045 - val_rmse: 0.0671
# Epoch 129/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0325 - mse: 0.0024 - rmse: 0.0489 - val_loss: 0.0046 - val_mae: 0.0399 - val_mse: 0.0046 - val_rmse: 0.0677
# Epoch 130/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0330 - mse: 0.0025 - rmse: 0.0493 - val_loss: 0.0050 - val_mae: 0.0378 - val_mse: 0.0050 - val_rmse: 0.0708
# Epoch 131/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0334 - mse: 0.0025 - rmse: 0.0501 - val_loss: 0.0043 - val_mae: 0.0352 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 132/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0325 - mse: 0.0024 - rmse: 0.0487 - val_loss: 0.0043 - val_mae: 0.0367 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 133/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0328 - mse: 0.0024 - rmse: 0.0490 - val_loss: 0.0046 - val_mae: 0.0415 - val_mse: 0.0046 - val_rmse: 0.0679
# Epoch 134/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0351 - mse: 0.0027 - rmse: 0.0517 - val_loss: 0.0044 - val_mae: 0.0268 - val_mse: 0.0044 - val_rmse: 0.0667
# Epoch 135/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0340 - mse: 0.0026 - rmse: 0.0508 - val_loss: 0.0045 - val_mae: 0.0336 - val_mse: 0.0045 - val_rmse: 0.0672
# Epoch 136/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0342 - mse: 0.0026 - rmse: 0.0507 - val_loss: 0.0043 - val_mae: 0.0346 - val_mse: 0.0043 - val_rmse: 0.0653
# Epoch 137/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0031 - mae: 0.0384 - mse: 0.0031 - rmse: 0.0548 - val_loss: 0.0043 - val_mae: 0.0337 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 138/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0042 - mae: 0.0471 - mse: 0.0042 - rmse: 0.0645 - val_loss: 0.0043 - val_mae: 0.0356 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 139/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0527 - mse: 0.0050 - rmse: 0.0705 - val_loss: 0.0066 - val_mae: 0.0614 - val_mse: 0.0066 - val_rmse: 0.0812
# Epoch 140/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0066 - mae: 0.0613 - mse: 0.0066 - rmse: 0.0807 - val_loss: 0.0082 - val_mae: 0.0733 - val_mse: 0.0082 - val_rmse: 0.0908
# Epoch 141/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0066 - mae: 0.0617 - mse: 0.0066 - rmse: 0.0807 - val_loss: 0.0083 - val_mae: 0.0722 - val_mse: 0.0083 - val_rmse: 0.0909
# Epoch 142/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0065 - mae: 0.0624 - mse: 0.0065 - rmse: 0.0804 - val_loss: 0.0100 - val_mae: 0.0845 - val_mse: 0.0100 - val_rmse: 0.1001
# Epoch 143/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0538 - mse: 0.0050 - rmse: 0.0706 - val_loss: 0.0068 - val_mae: 0.0621 - val_mse: 0.0068 - val_rmse: 0.0827
# Epoch 144/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0367 - mse: 0.0028 - rmse: 0.0528 - val_loss: 0.0045 - val_mae: 0.0355 - val_mse: 0.0045 - val_rmse: 0.0673
# Epoch 145/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0357 - mse: 0.0028 - rmse: 0.0521 - val_loss: 0.0045 - val_mae: 0.0340 - val_mse: 0.0045 - val_rmse: 0.0670
# Epoch 146/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0358 - mse: 0.0028 - rmse: 0.0523 - val_loss: 0.0047 - val_mae: 0.0379 - val_mse: 0.0047 - val_rmse: 0.0685
# Epoch 147/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0347 - mse: 0.0027 - rmse: 0.0513 - val_loss: 0.0048 - val_mae: 0.0392 - val_mse: 0.0048 - val_rmse: 0.0694
# Epoch 148/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0320 - mse: 0.0024 - rmse: 0.0485 - val_loss: 0.0046 - val_mae: 0.0400 - val_mse: 0.0046 - val_rmse: 0.0678
# Epoch 149/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0307 - mse: 0.0022 - rmse: 0.0468 - val_loss: 0.0046 - val_mae: 0.0414 - val_mse: 0.0046 - val_rmse: 0.0676
# Epoch 150/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0303 - mse: 0.0022 - rmse: 0.0464 - val_loss: 0.0043 - val_mae: 0.0358 - val_mse: 0.0043 - val_rmse: 0.0659
# Epoch 151/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0305 - mse: 0.0022 - rmse: 0.0467 - val_loss: 0.0047 - val_mae: 0.0412 - val_mse: 0.0047 - val_rmse: 0.0689
# Epoch 152/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0302 - mse: 0.0022 - rmse: 0.0465 - val_loss: 0.0047 - val_mae: 0.0419 - val_mse: 0.0047 - val_rmse: 0.0684
# Epoch 153/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0304 - mse: 0.0022 - rmse: 0.0465 - val_loss: 0.0045 - val_mae: 0.0393 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 154/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0298 - mse: 0.0022 - rmse: 0.0461 - val_loss: 0.0044 - val_mae: 0.0385 - val_mse: 0.0044 - val_rmse: 0.0666
# Epoch 155/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0304 - mse: 0.0022 - rmse: 0.0466 - val_loss: 0.0045 - val_mae: 0.0379 - val_mse: 0.0045 - val_rmse: 0.0672
# Epoch 156/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0302 - mse: 0.0022 - rmse: 0.0464 - val_loss: 0.0045 - val_mae: 0.0369 - val_mse: 0.0045 - val_rmse: 0.0667
# Epoch 157/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0301 - mse: 0.0022 - rmse: 0.0462 - val_loss: 0.0043 - val_mae: 0.0353 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 158/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0308 - mse: 0.0022 - rmse: 0.0467 - val_loss: 0.0049 - val_mae: 0.0441 - val_mse: 0.0049 - val_rmse: 0.0698
# Epoch 159/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0307 - mse: 0.0022 - rmse: 0.0467 - val_loss: 0.0048 - val_mae: 0.0427 - val_mse: 0.0048 - val_rmse: 0.0694
# Epoch 160/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0312 - mse: 0.0023 - rmse: 0.0472 - val_loss: 0.0046 - val_mae: 0.0411 - val_mse: 0.0046 - val_rmse: 0.0675
# Epoch 161/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0311 - mse: 0.0023 - rmse: 0.0469 - val_loss: 0.0045 - val_mae: 0.0385 - val_mse: 0.0045 - val_rmse: 0.0670
# Epoch 162/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0347 - mse: 0.0026 - rmse: 0.0505 - val_loss: 0.0044 - val_mae: 0.0371 - val_mse: 0.0044 - val_rmse: 0.0666
# Epoch 163/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0349 - mse: 0.0026 - rmse: 0.0508 - val_loss: 0.0046 - val_mae: 0.0370 - val_mse: 0.0046 - val_rmse: 0.0675
# Epoch 164/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0030 - mae: 0.0383 - mse: 0.0030 - rmse: 0.0542 - val_loss: 0.0046 - val_mae: 0.0371 - val_mse: 0.0046 - val_rmse: 0.0677
# Epoch 165/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039 - rmse: 0.0614 - val_loss: 0.0052 - val_mae: 0.0358 - val_mse: 0.0052 - val_rmse: 0.0723
# Epoch 166/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0046 - mae: 0.0498 - mse: 0.0046 - rmse: 0.0674 - val_loss: 0.0077 - val_mae: 0.0515 - val_mse: 0.0077 - val_rmse: 0.0878
# Epoch 167/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0052 - mae: 0.0535 - mse: 0.0052 - rmse: 0.0718 - val_loss: 0.0075 - val_mae: 0.0536 - val_mse: 0.0075 - val_rmse: 0.0864
# Epoch 168/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0517 - mse: 0.0050 - rmse: 0.0704 - val_loss: 0.0061 - val_mae: 0.0422 - val_mse: 0.0061 - val_rmse: 0.0779
# Epoch 169/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0043 - mae: 0.0467 - mse: 0.0043 - rmse: 0.0653 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0066 - val_rmse: 0.0812
# Epoch 170/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0332 - mse: 0.0026 - rmse: 0.0504 - val_loss: 0.0043 - val_mae: 0.0345 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 171/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0289 - mse: 0.0021 - rmse: 0.0451 - val_loss: 0.0045 - val_mae: 0.0406 - val_mse: 0.0045 - val_rmse: 0.0672
# Epoch 172/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0295 - mse: 0.0021 - rmse: 0.0454 - val_loss: 0.0050 - val_mae: 0.0442 - val_mse: 0.0050 - val_rmse: 0.0708
# Epoch 173/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0022 - mae: 0.0306 - mse: 0.0022 - rmse: 0.0464 - val_loss: 0.0046 - val_mae: 0.0410 - val_mse: 0.0046 - val_rmse: 0.0675
# Epoch 174/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0285 - mse: 0.0021 - rmse: 0.0448 - val_loss: 0.0044 - val_mae: 0.0324 - val_mse: 0.0044 - val_rmse: 0.0663
# Epoch 175/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0294 - mse: 0.0021 - rmse: 0.0456 - val_loss: 0.0043 - val_mae: 0.0322 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 176/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0290 - mse: 0.0021 - rmse: 0.0453 - val_loss: 0.0043 - val_mae: 0.0361 - val_mse: 0.0043 - val_rmse: 0.0656
# Epoch 177/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0282 - mse: 0.0020 - rmse: 0.0444 - val_loss: 0.0044 - val_mae: 0.0382 - val_mse: 0.0044 - val_rmse: 0.0662
# Epoch 178/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0282 - mse: 0.0020 - rmse: 0.0442 - val_loss: 0.0044 - val_mae: 0.0386 - val_mse: 0.0044 - val_rmse: 0.0666
# Epoch 179/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0279 - mse: 0.0020 - rmse: 0.0441 - val_loss: 0.0043 - val_mae: 0.0342 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 180/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0021 - mae: 0.0288 - mse: 0.0021 - rmse: 0.0451 - val_loss: 0.0045 - val_mae: 0.0315 - val_mse: 0.0045 - val_rmse: 0.0667
# Epoch 181/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0295 - mse: 0.0021 - rmse: 0.0458 - val_loss: 0.0041 - val_mae: 0.0278 - val_mse: 0.0041 - val_rmse: 0.0639
# Epoch 182/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0279 - mse: 0.0020 - rmse: 0.0443 - val_loss: 0.0042 - val_mae: 0.0313 - val_mse: 0.0042 - val_rmse: 0.0646
# Epoch 183/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0279 - mse: 0.0020 - rmse: 0.0443 - val_loss: 0.0042 - val_mae: 0.0322 - val_mse: 0.0042 - val_rmse: 0.0645
# Epoch 184/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0283 - mse: 0.0020 - rmse: 0.0445 - val_loss: 0.0042 - val_mae: 0.0317 - val_mse: 0.0042 - val_rmse: 0.0648
# Epoch 185/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0274 - mse: 0.0020 - rmse: 0.0438 - val_loss: 0.0042 - val_mae: 0.0333 - val_mse: 0.0042 - val_rmse: 0.0646
# Epoch 186/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0270 - mse: 0.0019 - rmse: 0.0435 - val_loss: 0.0041 - val_mae: 0.0293 - val_mse: 0.0041 - val_rmse: 0.0641
# Epoch 187/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0267 - mse: 0.0019 - rmse: 0.0431 - val_loss: 0.0042 - val_mae: 0.0334 - val_mse: 0.0042 - val_rmse: 0.0650
# Epoch 188/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0273 - mse: 0.0019 - rmse: 0.0436 - val_loss: 0.0041 - val_mae: 0.0327 - val_mse: 0.0041 - val_rmse: 0.0643
# Epoch 189/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0266 - mse: 0.0019 - rmse: 0.0430 - val_loss: 0.0041 - val_mae: 0.0319 - val_mse: 0.0041 - val_rmse: 0.0642
# Epoch 190/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0266 - mse: 0.0019 - rmse: 0.0429 - val_loss: 0.0042 - val_mae: 0.0335 - val_mse: 0.0042 - val_rmse: 0.0647
# Epoch 191/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0262 - mse: 0.0019 - rmse: 0.0426 - val_loss: 0.0041 - val_mae: 0.0303 - val_mse: 0.0041 - val_rmse: 0.0638
# Epoch 192/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0291 - mse: 0.0021 - rmse: 0.0450 - val_loss: 0.0043 - val_mae: 0.0367 - val_mse: 0.0043 - val_rmse: 0.0659
# Epoch 193/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0294 - mse: 0.0021 - rmse: 0.0451 - val_loss: 0.0043 - val_mae: 0.0352 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 194/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0295 - mse: 0.0021 - rmse: 0.0455 - val_loss: 0.0041 - val_mae: 0.0318 - val_mse: 0.0041 - val_rmse: 0.0643
# Epoch 195/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0322 - mse: 0.0023 - rmse: 0.0479 - val_loss: 0.0044 - val_mae: 0.0380 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 196/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0372 - mse: 0.0028 - rmse: 0.0527 - val_loss: 0.0044 - val_mae: 0.0265 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 197/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0034 - mae: 0.0412 - mse: 0.0034 - rmse: 0.0576 - val_loss: 0.0054 - val_mae: 0.0347 - val_mse: 0.0054 - val_rmse: 0.0734
# Epoch 198/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0526 - mse: 0.0050 - rmse: 0.0704 - val_loss: 0.0057 - val_mae: 0.0414 - val_mse: 0.0057 - val_rmse: 0.0758
# Epoch 199/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0066 - mae: 0.0609 - mse: 0.0066 - rmse: 0.0808 - val_loss: 0.0061 - val_mae: 0.0497 - val_mse: 0.0061 - val_rmse: 0.0784
# Epoch 200/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0072 - mae: 0.0625 - mse: 0.0072 - rmse: 0.0845 - val_loss: 0.0089 - val_mae: 0.0549 - val_mse: 0.0089 - val_rmse: 0.0945
# Epoch 201/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0060 - mae: 0.0556 - mse: 0.0060 - rmse: 0.0771 - val_loss: 0.0084 - val_mae: 0.0492 - val_mse: 0.0084 - val_rmse: 0.0914
# Epoch 202/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0053 - mae: 0.0509 - mse: 0.0053 - rmse: 0.0726 - val_loss: 0.0051 - val_mae: 0.0379 - val_mse: 0.0051 - val_rmse: 0.0717
# Epoch 203/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0036 - mae: 0.0408 - mse: 0.0036 - rmse: 0.0596 - val_loss: 0.0070 - val_mae: 0.0491 - val_mse: 0.0070 - val_rmse: 0.0839
# Epoch 204/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0358 - mse: 0.0028 - rmse: 0.0528 - val_loss: 0.0052 - val_mae: 0.0376 - val_mse: 0.0052 - val_rmse: 0.0722
# Epoch 205/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0308 - mse: 0.0023 - rmse: 0.0476 - val_loss: 0.0043 - val_mae: 0.0320 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 206/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0278 - mse: 0.0020 - rmse: 0.0441 - val_loss: 0.0043 - val_mae: 0.0306 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 207/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0277 - mse: 0.0020 - rmse: 0.0438 - val_loss: 0.0042 - val_mae: 0.0288 - val_mse: 0.0042 - val_rmse: 0.0645
# Epoch 208/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0272 - mse: 0.0019 - rmse: 0.0435 - val_loss: 0.0042 - val_mae: 0.0329 - val_mse: 0.0042 - val_rmse: 0.0649
# Epoch 209/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0271 - mse: 0.0019 - rmse: 0.0432 - val_loss: 0.0042 - val_mae: 0.0331 - val_mse: 0.0042 - val_rmse: 0.0650
# Epoch 210/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0263 - mse: 0.0019 - rmse: 0.0425 - val_loss: 0.0040 - val_mae: 0.0292 - val_mse: 0.0040 - val_rmse: 0.0632
# Epoch 211/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0257 - mse: 0.0018 - rmse: 0.0421 - val_loss: 0.0040 - val_mae: 0.0272 - val_mse: 0.0040 - val_rmse: 0.0629
# Epoch 212/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0262 - mse: 0.0019 - rmse: 0.0426 - val_loss: 0.0040 - val_mae: 0.0288 - val_mse: 0.0040 - val_rmse: 0.0630
# Epoch 213/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0270 - mse: 0.0019 - rmse: 0.0430 - val_loss: 0.0042 - val_mae: 0.0358 - val_mse: 0.0042 - val_rmse: 0.0650
# Epoch 214/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0287 - mse: 0.0020 - rmse: 0.0446 - val_loss: 0.0041 - val_mae: 0.0320 - val_mse: 0.0041 - val_rmse: 0.0641
# Epoch 215/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0259 - mse: 0.0018 - rmse: 0.0423 - val_loss: 0.0040 - val_mae: 0.0296 - val_mse: 0.0040 - val_rmse: 0.0635
# Epoch 216/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0255 - mse: 0.0018 - rmse: 0.0420 - val_loss: 0.0041 - val_mae: 0.0324 - val_mse: 0.0041 - val_rmse: 0.0641
# Epoch 217/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0264 - mse: 0.0019 - rmse: 0.0425 - val_loss: 0.0041 - val_mae: 0.0326 - val_mse: 0.0041 - val_rmse: 0.0641
# Epoch 218/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0262 - mse: 0.0018 - rmse: 0.0425 - val_loss: 0.0040 - val_mae: 0.0296 - val_mse: 0.0040 - val_rmse: 0.0636
# Epoch 219/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0263 - mse: 0.0019 - rmse: 0.0426 - val_loss: 0.0040 - val_mae: 0.0293 - val_mse: 0.0040 - val_rmse: 0.0633
# Epoch 220/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0258 - mse: 0.0018 - rmse: 0.0419 - val_loss: 0.0041 - val_mae: 0.0323 - val_mse: 0.0041 - val_rmse: 0.0642
# Epoch 221/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0253 - mse: 0.0018 - rmse: 0.0418 - val_loss: 0.0042 - val_mae: 0.0332 - val_mse: 0.0042 - val_rmse: 0.0646
# Epoch 222/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018 - mae: 0.0250 - mse: 0.0018 - rmse: 0.0413 - val_loss: 0.0040 - val_mae: 0.0292 - val_mse: 0.0040 - val_rmse: 0.0634
# Epoch 223/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0263 - mse: 0.0019 - rmse: 0.0424 - val_loss: 0.0041 - val_mae: 0.0284 - val_mse: 0.0041 - val_rmse: 0.0640
# Epoch 224/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0279 - mse: 0.0020 - rmse: 0.0439 - val_loss: 0.0041 - val_mae: 0.0306 - val_mse: 0.0041 - val_rmse: 0.0642
# Epoch 225/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0285 - mse: 0.0020 - rmse: 0.0445 - val_loss: 0.0041 - val_mae: 0.0317 - val_mse: 0.0041 - val_rmse: 0.0642
# Epoch 226/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0289 - mse: 0.0021 - rmse: 0.0449 - val_loss: 0.0043 - val_mae: 0.0295 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 227/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0324 - mse: 0.0024 - rmse: 0.0480 - val_loss: 0.0041 - val_mae: 0.0299 - val_mse: 0.0041 - val_rmse: 0.0638
# Epoch 228/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0344 - mse: 0.0025 - rmse: 0.0496 - val_loss: 0.0043 - val_mae: 0.0264 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 229/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0029 - mae: 0.0373 - mse: 0.0029 - rmse: 0.0532 - val_loss: 0.0042 - val_mae: 0.0291 - val_mse: 0.0042 - val_rmse: 0.0651
# Epoch 230/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mae: 0.0364 - mse: 0.0028 - rmse: 0.0521 - val_loss: 0.0050 - val_mae: 0.0335 - val_mse: 0.0050 - val_rmse: 0.0710
# Epoch 231/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0037 - mae: 0.0444 - mse: 0.0037 - rmse: 0.0609 - val_loss: 0.0060 - val_mae: 0.0440 - val_mse: 0.0060 - val_rmse: 0.0773
# Epoch 232/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0035 - mae: 0.0428 - mse: 0.0035 - rmse: 0.0591 - val_loss: 0.0061 - val_mae: 0.0442 - val_mse: 0.0061 - val_rmse: 0.0784
# Epoch 233/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0033 - mae: 0.0407 - mse: 0.0033 - rmse: 0.0572 - val_loss: 0.0061 - val_mae: 0.0455 - val_mse: 0.0061 - val_rmse: 0.0782
# Epoch 234/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0029 - mae: 0.0364 - mse: 0.0029 - rmse: 0.0534 - val_loss: 0.0045 - val_mae: 0.0313 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 235/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0274 - mse: 0.0020 - rmse: 0.0439 - val_loss: 0.0043 - val_mae: 0.0292 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 236/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0309 - mse: 0.0023 - rmse: 0.0470 - val_loss: 0.0044 - val_mae: 0.0346 - val_mse: 0.0044 - val_rmse: 0.0662
# Epoch 237/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0356 - mse: 0.0027 - rmse: 0.0514 - val_loss: 0.0050 - val_mae: 0.0446 - val_mse: 0.0050 - val_rmse: 0.0707
# Epoch 238/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - mae: 0.0361 - mse: 0.0027 - rmse: 0.0515 - val_loss: 0.0051 - val_mae: 0.0455 - val_mse: 0.0051 - val_rmse: 0.0715
# Epoch 239/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023 - mae: 0.0323 - mse: 0.0023 - rmse: 0.0479 - val_loss: 0.0043 - val_mae: 0.0322 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 240/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0283 - mse: 0.0020 - rmse: 0.0438 - val_loss: 0.0041 - val_mae: 0.0328 - val_mse: 0.0041 - val_rmse: 0.0642
# Epoch 241/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0026 - mae: 0.0355 - mse: 0.0026 - rmse: 0.0506 - val_loss: 0.0049 - val_mae: 0.0374 - val_mse: 0.0049 - val_rmse: 0.0698
# Epoch 242/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0032 - mae: 0.0404 - mse: 0.0032 - rmse: 0.0561 - val_loss: 0.0075 - val_mae: 0.0556 - val_mse: 0.0075 - val_rmse: 0.0866
# Epoch 243/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0045 - mae: 0.0500 - mse: 0.0045 - rmse: 0.0664 - val_loss: 0.0129 - val_mae: 0.0879 - val_mse: 0.0129 - val_rmse: 0.1137
# Epoch 244/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0065 - mae: 0.0618 - mse: 0.0065 - rmse: 0.0803 - val_loss: 0.0148 - val_mae: 0.1088 - val_mse: 0.0148 - val_rmse: 0.1215
# Epoch 245/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0127 - mae: 0.0877 - mse: 0.0127 - rmse: 0.1120 - val_loss: 0.0083 - val_mae: 0.0610 - val_mse: 0.0083 - val_rmse: 0.0912
# Epoch 246/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0202 - mae: 0.1128 - mse: 0.0202 - rmse: 0.1418 - val_loss: 0.0334 - val_mae: 0.1646 - val_mse: 0.0334 - val_rmse: 0.1828
# Epoch 247/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0171 - mae: 0.1053 - mse: 0.0171 - rmse: 0.1305 - val_loss: 0.0210 - val_mae: 0.1246 - val_mse: 0.0210 - val_rmse: 0.1448
# Epoch 248/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0129 - mae: 0.0903 - mse: 0.0129 - rmse: 0.1129 - val_loss: 0.0151 - val_mae: 0.0902 - val_mse: 0.0151 - val_rmse: 0.1229
# Epoch 249/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0046 - mae: 0.0506 - mse: 0.0046 - rmse: 0.0676 - val_loss: 0.0045 - val_mae: 0.0318 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 250/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - mae: 0.0476 - mse: 0.0041 - rmse: 0.0641 - val_loss: 0.0044 - val_mae: 0.0270 - val_mse: 0.0044 - val_rmse: 0.0660
# Epoch 251/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034 - rmse: 0.0586 - val_loss: 0.0084 - val_mae: 0.0668 - val_mse: 0.0084 - val_rmse: 0.0919
# Epoch 252/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0029 - mae: 0.0374 - mse: 0.0029 - rmse: 0.0532 - val_loss: 0.0112 - val_mae: 0.0823 - val_mse: 0.0112 - val_rmse: 0.1057
# Epoch 253/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - mae: 0.0338 - mse: 0.0025 - rmse: 0.0499 - val_loss: 0.0079 - val_mae: 0.0620 - val_mse: 0.0079 - val_rmse: 0.0887
# Epoch 254/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0021 - mae: 0.0292 - mse: 0.0021 - rmse: 0.0457 - val_loss: 0.0053 - val_mae: 0.0405 - val_mse: 0.0053 - val_rmse: 0.0729
# Epoch 255/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0020 - mae: 0.0277 - mse: 0.0020 - rmse: 0.0440 - val_loss: 0.0049 - val_mae: 0.0357 - val_mse: 0.0049 - val_rmse: 0.0698
# Epoch 256/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0266 - mse: 0.0019 - rmse: 0.0429 - val_loss: 0.0046 - val_mae: 0.0323 - val_mse: 0.0046 - val_rmse: 0.0682
# Epoch 257/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0019 - mae: 0.0265 - mse: 0.0019 - rmse: 0.0428 - val_loss: 0.0048 - val_mae: 0.0341 - val_mse: 0.0048 - val_rmse: 0.0691
# Epoch 258/1000
# ...
# Epoch 919/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.5666e-04 - mae: 0.0135 - mse: 5.5666e-04 - rmse: 0.0231 - val_loss: 0.0044 - val_mae: 0.0246 - val_mse: 0.0044 - val_rmse: 0.0660
# Epoch 920/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2426e-04 - mae: 0.0123 - mse: 5.2426e-04 - rmse: 0.0225 - val_loss: 0.0044 - val_mae: 0.0155 - val_mse: 0.0044 - val_rmse: 0.0661
# Epoch 921/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1907e-04 - mae: 0.0121 - mse: 5.1907e-04 - rmse: 0.0223 - val_loss: 0.0045 - val_mae: 0.0154 - val_mse: 0.0045 - val_rmse: 0.0669
# Epoch 922/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0210e-04 - mae: 0.0116 - mse: 5.0210e-04 - rmse: 0.0218 - val_loss: 0.0043 - val_mae: 0.0198 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 923/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1874e-04 - mae: 0.0123 - mse: 5.1874e-04 - rmse: 0.0223 - val_loss: 0.0044 - val_mae: 0.0203 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 924/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2956e-04 - mae: 0.0127 - mse: 5.2956e-04 - rmse: 0.0225 - val_loss: 0.0047 - val_mae: 0.0221 - val_mse: 0.0047 - val_rmse: 0.0682
# Epoch 925/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6220e-04 - mae: 0.0135 - mse: 5.6220e-04 - rmse: 0.0233 - val_loss: 0.0043 - val_mae: 0.0159 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 926/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1251e-04 - mae: 0.0121 - mse: 5.1251e-04 - rmse: 0.0221 - val_loss: 0.0043 - val_mae: 0.0172 - val_mse: 0.0043 - val_rmse: 0.0652
# Epoch 927/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.3016e-04 - mae: 0.0125 - mse: 5.3016e-04 - rmse: 0.0226 - val_loss: 0.0044 - val_mae: 0.0173 - val_mse: 0.0044 - val_rmse: 0.0661
# Epoch 928/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.2206e-04 - mae: 0.0121 - mse: 5.2206e-04 - rmse: 0.0223 - val_loss: 0.0047 - val_mae: 0.0217 - val_mse: 0.0047 - val_rmse: 0.0687
# Epoch 929/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.4736e-04 - mae: 0.0130 - mse: 5.4736e-04 - rmse: 0.0229 - val_loss: 0.0046 - val_mae: 0.0186 - val_mse: 0.0046 - val_rmse: 0.0676
# Epoch 930/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0490e-04 - mae: 0.0116 - mse: 5.0490e-04 - rmse: 0.0219 - val_loss: 0.0044 - val_mae: 0.0205 - val_mse: 0.0044 - val_rmse: 0.0661
# Epoch 931/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.7432e-04 - mae: 0.0137 - mse: 5.7432e-04 - rmse: 0.0235 - val_loss: 0.0045 - val_mae: 0.0254 - val_mse: 0.0045 - val_rmse: 0.0673
# Epoch 932/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6231e-04 - mae: 0.0132 - mse: 5.6231e-04 - rmse: 0.0232 - val_loss: 0.0048 - val_mae: 0.0225 - val_mse: 0.0048 - val_rmse: 0.0690
# Epoch 933/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6233e-04 - mae: 0.0132 - mse: 5.6233e-04 - rmse: 0.0233 - val_loss: 0.0047 - val_mae: 0.0218 - val_mse: 0.0047 - val_rmse: 0.0689
# Epoch 934/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.3960e-04 - mae: 0.0127 - mse: 5.3960e-04 - rmse: 0.0228 - val_loss: 0.0047 - val_mae: 0.0211 - val_mse: 0.0047 - val_rmse: 0.0685
# Epoch 935/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2111e-04 - mae: 0.0123 - mse: 5.2111e-04 - rmse: 0.0223 - val_loss: 0.0043 - val_mae: 0.0188 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 936/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.7943e-04 - mae: 0.0139 - mse: 5.7943e-04 - rmse: 0.0237 - val_loss: 0.0042 - val_mae: 0.0172 - val_mse: 0.0042 - val_rmse: 0.0650
# Epoch 937/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0995e-04 - mae: 0.0121 - mse: 5.0995e-04 - rmse: 0.0221 - val_loss: 0.0045 - val_mae: 0.0200 - val_mse: 0.0045 - val_rmse: 0.0669
# Epoch 938/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.4287e-04 - mae: 0.0131 - mse: 5.4287e-04 - rmse: 0.0229 - val_loss: 0.0046 - val_mae: 0.0200 - val_mse: 0.0046 - val_rmse: 0.0675
# Epoch 939/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1440e-04 - mae: 0.0121 - mse: 5.1440e-04 - rmse: 0.0222 - val_loss: 0.0043 - val_mae: 0.0172 - val_mse: 0.0043 - val_rmse: 0.0652
# Epoch 940/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2517e-04 - mae: 0.0126 - mse: 5.2517e-04 - rmse: 0.0224 - val_loss: 0.0044 - val_mae: 0.0187 - val_mse: 0.0044 - val_rmse: 0.0663
# Epoch 941/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9371e-04 - mae: 0.0116 - mse: 4.9371e-04 - rmse: 0.0217 - val_loss: 0.0046 - val_mae: 0.0203 - val_mse: 0.0046 - val_rmse: 0.0680
# Epoch 942/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2926e-04 - mae: 0.0125 - mse: 5.2926e-04 - rmse: 0.0225 - val_loss: 0.0047 - val_mae: 0.0172 - val_mse: 0.0047 - val_rmse: 0.0683
# Epoch 943/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2991e-04 - mae: 0.0122 - mse: 5.2991e-04 - rmse: 0.0225 - val_loss: 0.0046 - val_mae: 0.0246 - val_mse: 0.0046 - val_rmse: 0.0676
# Epoch 944/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6278e-04 - mae: 0.0135 - mse: 5.6278e-04 - rmse: 0.0233 - val_loss: 0.0045 - val_mae: 0.0248 - val_mse: 0.0045 - val_rmse: 0.0667
# Epoch 945/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1331e-04 - mae: 0.0124 - mse: 5.1331e-04 - rmse: 0.0222 - val_loss: 0.0044 - val_mae: 0.0161 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 946/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9953e-04 - mae: 0.0117 - mse: 4.9953e-04 - rmse: 0.0218 - val_loss: 0.0044 - val_mae: 0.0169 - val_mse: 0.0044 - val_rmse: 0.0667
# Epoch 947/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0093e-04 - mae: 0.0120 - mse: 5.0093e-04 - rmse: 0.0219 - val_loss: 0.0043 - val_mae: 0.0169 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 948/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0926e-04 - mae: 0.0124 - mse: 5.0926e-04 - rmse: 0.0221 - val_loss: 0.0044 - val_mae: 0.0186 - val_mse: 0.0044 - val_rmse: 0.0663
# Epoch 949/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9763e-04 - mae: 0.0119 - mse: 4.9763e-04 - rmse: 0.0218 - val_loss: 0.0046 - val_mae: 0.0204 - val_mse: 0.0046 - val_rmse: 0.0678
# Epoch 950/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6294e-04 - mae: 0.0139 - mse: 5.6294e-04 - rmse: 0.0233 - val_loss: 0.0045 - val_mae: 0.0179 - val_mse: 0.0045 - val_rmse: 0.0667
# Epoch 951/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9280e-04 - mae: 0.0121 - mse: 4.9280e-04 - rmse: 0.0217 - val_loss: 0.0043 - val_mae: 0.0182 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 952/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.2028e-04 - mae: 0.0126 - mse: 5.2028e-04 - rmse: 0.0224 - val_loss: 0.0043 - val_mae: 0.0199 - val_mse: 0.0043 - val_rmse: 0.0659
# Epoch 953/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0143e-04 - mae: 0.0121 - mse: 5.0143e-04 - rmse: 0.0219 - val_loss: 0.0046 - val_mae: 0.0184 - val_mse: 0.0046 - val_rmse: 0.0676
# Epoch 954/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.4308e-04 - mae: 0.0133 - mse: 5.4308e-04 - rmse: 0.0229 - val_loss: 0.0046 - val_mae: 0.0206 - val_mse: 0.0046 - val_rmse: 0.0677
# Epoch 955/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.5384e-04 - mae: 0.0130 - mse: 5.5384e-04 - rmse: 0.0232 - val_loss: 0.0045 - val_mae: 0.0198 - val_mse: 0.0045 - val_rmse: 0.0669
# Epoch 956/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1488e-04 - mae: 0.0120 - mse: 5.1488e-04 - rmse: 0.0223 - val_loss: 0.0044 - val_mae: 0.0200 - val_mse: 0.0044 - val_rmse: 0.0662
# Epoch 957/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0653e-04 - mae: 0.0124 - mse: 5.0653e-04 - rmse: 0.0220 - val_loss: 0.0047 - val_mae: 0.0206 - val_mse: 0.0047 - val_rmse: 0.0688
# Epoch 958/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1150e-04 - mae: 0.0123 - mse: 5.1150e-04 - rmse: 0.0222 - val_loss: 0.0044 - val_mae: 0.0171 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 959/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8742e-04 - mae: 0.0119 - mse: 4.8742e-04 - rmse: 0.0216 - val_loss: 0.0044 - val_mae: 0.0165 - val_mse: 0.0044 - val_rmse: 0.0660
# Epoch 960/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8376e-04 - mae: 0.0116 - mse: 4.8376e-04 - rmse: 0.0215 - val_loss: 0.0044 - val_mae: 0.0172 - val_mse: 0.0044 - val_rmse: 0.0666
# Epoch 961/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8092e-04 - mae: 0.0113 - mse: 4.8092e-04 - rmse: 0.0214 - val_loss: 0.0045 - val_mae: 0.0164 - val_mse: 0.0045 - val_rmse: 0.0672
# Epoch 962/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8442e-04 - mae: 0.0117 - mse: 4.8442e-04 - rmse: 0.0215 - val_loss: 0.0044 - val_mae: 0.0182 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 963/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1189e-04 - mae: 0.0126 - mse: 5.1189e-04 - rmse: 0.0221 - val_loss: 0.0044 - val_mae: 0.0215 - val_mse: 0.0044 - val_rmse: 0.0663
# Epoch 964/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.3542e-04 - mae: 0.0131 - mse: 5.3542e-04 - rmse: 0.0228 - val_loss: 0.0043 - val_mae: 0.0187 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 965/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7588e-04 - mae: 0.0115 - mse: 4.7588e-04 - rmse: 0.0213 - val_loss: 0.0045 - val_mae: 0.0203 - val_mse: 0.0045 - val_rmse: 0.0668
# Epoch 966/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8950e-04 - mae: 0.0119 - mse: 4.8950e-04 - rmse: 0.0217 - val_loss: 0.0044 - val_mae: 0.0177 - val_mse: 0.0044 - val_rmse: 0.0661
# Epoch 967/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6917e-04 - mae: 0.0113 - mse: 4.6917e-04 - rmse: 0.0211 - val_loss: 0.0045 - val_mae: 0.0165 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 968/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9120e-04 - mae: 0.0117 - mse: 4.9120e-04 - rmse: 0.0216 - val_loss: 0.0045 - val_mae: 0.0169 - val_mse: 0.0045 - val_rmse: 0.0670
# Epoch 969/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9238e-04 - mae: 0.0118 - mse: 4.9238e-04 - rmse: 0.0217 - val_loss: 0.0045 - val_mae: 0.0184 - val_mse: 0.0045 - val_rmse: 0.0670
# Epoch 970/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8219e-04 - mae: 0.0114 - mse: 4.8219e-04 - rmse: 0.0215 - val_loss: 0.0044 - val_mae: 0.0166 - val_mse: 0.0044 - val_rmse: 0.0663
# Epoch 971/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8361e-04 - mae: 0.0116 - mse: 4.8361e-04 - rmse: 0.0214 - val_loss: 0.0044 - val_mae: 0.0203 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 972/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.5945e-04 - mae: 0.0139 - mse: 5.5945e-04 - rmse: 0.0232 - val_loss: 0.0045 - val_mae: 0.0224 - val_mse: 0.0045 - val_rmse: 0.0670
# Epoch 973/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6936e-04 - mae: 0.0144 - mse: 5.6936e-04 - rmse: 0.0236 - val_loss: 0.0044 - val_mae: 0.0216 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 974/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7799e-04 - mae: 0.0116 - mse: 4.7799e-04 - rmse: 0.0214 - val_loss: 0.0043 - val_mae: 0.0160 - val_mse: 0.0043 - val_rmse: 0.0659
# Epoch 975/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7078e-04 - mae: 0.0112 - mse: 4.7078e-04 - rmse: 0.0212 - val_loss: 0.0043 - val_mae: 0.0191 - val_mse: 0.0043 - val_rmse: 0.0654
# Epoch 976/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7650e-04 - mae: 0.0115 - mse: 4.7650e-04 - rmse: 0.0214 - val_loss: 0.0047 - val_mae: 0.0200 - val_mse: 0.0047 - val_rmse: 0.0683
# Epoch 977/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9537e-04 - mae: 0.0122 - mse: 4.9537e-04 - rmse: 0.0218 - val_loss: 0.0045 - val_mae: 0.0162 - val_mse: 0.0045 - val_rmse: 0.0669
# Epoch 978/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6710e-04 - mae: 0.0112 - mse: 4.6710e-04 - rmse: 0.0211 - val_loss: 0.0044 - val_mae: 0.0194 - val_mse: 0.0044 - val_rmse: 0.0665
# Epoch 979/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7781e-04 - mae: 0.0116 - mse: 4.7781e-04 - rmse: 0.0214 - val_loss: 0.0044 - val_mae: 0.0161 - val_mse: 0.0044 - val_rmse: 0.0666
# Epoch 980/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7055e-04 - mae: 0.0112 - mse: 4.7055e-04 - rmse: 0.0212 - val_loss: 0.0045 - val_mae: 0.0158 - val_mse: 0.0045 - val_rmse: 0.0668
# Epoch 981/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.5381e-04 - mae: 0.0110 - mse: 4.5381e-04 - rmse: 0.0208 - val_loss: 0.0044 - val_mae: 0.0170 - val_mse: 0.0044 - val_rmse: 0.0667
# Epoch 982/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7866e-04 - mae: 0.0116 - mse: 4.7866e-04 - rmse: 0.0214 - val_loss: 0.0044 - val_mae: 0.0160 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 983/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.7678e-04 - mae: 0.0117 - mse: 4.7678e-04 - rmse: 0.0213 - val_loss: 0.0044 - val_mae: 0.0148 - val_mse: 0.0044 - val_rmse: 0.0660
# Epoch 984/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6920e-04 - mae: 0.0115 - mse: 4.6920e-04 - rmse: 0.0211 - val_loss: 0.0043 - val_mae: 0.0157 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 985/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.8608e-04 - mae: 0.0118 - mse: 4.8608e-04 - rmse: 0.0215 - val_loss: 0.0047 - val_mae: 0.0224 - val_mse: 0.0047 - val_rmse: 0.0682
# Epoch 986/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.3480e-04 - mae: 0.0132 - mse: 5.3480e-04 - rmse: 0.0227 - val_loss: 0.0047 - val_mae: 0.0219 - val_mse: 0.0047 - val_rmse: 0.0683
# Epoch 987/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.9102e-04 - mae: 0.0122 - mse: 4.9102e-04 - rmse: 0.0218 - val_loss: 0.0043 - val_mae: 0.0176 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 988/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.7898e-04 - mae: 0.0117 - mse: 4.7898e-04 - rmse: 0.0214 - val_loss: 0.0044 - val_mae: 0.0191 - val_mse: 0.0044 - val_rmse: 0.0662
# Epoch 989/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.5866e-04 - mae: 0.0111 - mse: 4.5866e-04 - rmse: 0.0209 - val_loss: 0.0045 - val_mae: 0.0162 - val_mse: 0.0045 - val_rmse: 0.0668
# Epoch 990/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.6984e-04 - mae: 0.0112 - mse: 4.6984e-04 - rmse: 0.0212 - val_loss: 0.0046 - val_mae: 0.0186 - val_mse: 0.0046 - val_rmse: 0.0677
# Epoch 991/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.8564e-04 - mae: 0.0120 - mse: 4.8564e-04 - rmse: 0.0216 - val_loss: 0.0044 - val_mae: 0.0157 - val_mse: 0.0044 - val_rmse: 0.0664
# Epoch 992/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.5959e-04 - mae: 0.0112 - mse: 4.5959e-04 - rmse: 0.0209 - val_loss: 0.0044 - val_mae: 0.0153 - val_mse: 0.0044 - val_rmse: 0.0660
# Epoch 993/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6862e-04 - mae: 0.0115 - mse: 4.6862e-04 - rmse: 0.0211 - val_loss: 0.0043 - val_mae: 0.0155 - val_mse: 0.0043 - val_rmse: 0.0657
# Epoch 994/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.6724e-04 - mae: 0.0117 - mse: 4.6724e-04 - rmse: 0.0211 - val_loss: 0.0044 - val_mae: 0.0160 - val_mse: 0.0044 - val_rmse: 0.0661
# Epoch 995/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.3492e-04 - mae: 0.0131 - mse: 5.3492e-04 - rmse: 0.0226 - val_loss: 0.0043 - val_mae: 0.0220 - val_mse: 0.0043 - val_rmse: 0.0655
# Epoch 996/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.7875e-04 - mae: 0.0162 - mse: 6.7875e-04 - rmse: 0.0257 - val_loss: 0.0043 - val_mae: 0.0235 - val_mse: 0.0043 - val_rmse: 0.0658
# Epoch 997/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 7.4190e-04 - mae: 0.0174 - mse: 7.4190e-04 - rmse: 0.0269 - val_loss: 0.0045 - val_mae: 0.0297 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 998/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.7455e-04 - mae: 0.0167 - mse: 6.7455e-04 - rmse: 0.0258 - val_loss: 0.0045 - val_mae: 0.0246 - val_mse: 0.0045 - val_rmse: 0.0674
# Epoch 999/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.4811e-04 - mae: 0.0134 - mse: 5.4811e-04 - rmse: 0.0230 - val_loss: 0.0049 - val_mae: 0.0234 - val_mse: 0.0049 - val_rmse: 0.0700
# Epoch 1000/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.9885e-04 - mae: 0.0141 - mse: 5.9885e-04 - rmse: 0.0242 - val_loss: 0.0046 - val_mae: 0.0210 - val_mse: 0.0046 - val_rmse: 0.0679

# %%
# Plot the loss and accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'][-200:], label='Training Loss')
plt.plot(history.history['val_loss'][-200:], label='Validation Loss')
plt.title('Training Loss Over Last 200 Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Make predictions on the test set
predictions = model.predict(test_set)

# Extract the actual values from the test set
actuals = np.concatenate([y for x, y in test_set], axis=0)


print(predictions.shape)
print(actuals.shape)

# Flatten the predictions and actuals
predictions = predictions.flatten()
actuals = actuals.flatten()

# # Inverse transform the predictions and actuals
# predictions = scaler.inverse_transform(predictions.reshape(-1, 2)).flatten()
# actuals = scaler.inverse_transform(actuals.reshape(-1, 2)).flatten()

# Plot the predicted vs actual outputs
plt.figure(figsize=(10, 6))
plt.plot(actuals, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('Predicted vs Actual Outputs')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (27, 32, 1)
# (27, 32, 1)

# %%
y_pred_train = model.predict(train_set)
y_train = np.concatenate([y for x, y in train_set], axis=0)

y_pred_train = y_pred_train.flatten()
y_train = y_train.flatten()

plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Actual')
plt.plot(y_pred_train, label='Predicted')
plt.title('Predicted vs Actual Outputs (Train)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step

# %%
model.save_weights('corrector-ae.weights.h5')

# %%
# Load the 'beirut-daily-precipitation.csv' file
beirut_df = pd.read_csv('data/beirut-hourly-precipitation.csv')

# Create a windowed dataset from df['value'] without shuffling
beirut_values = beirut_df['value'].values
beirut_values = scaler.transform(beirut_values.reshape(-1, 1)).flatten()
beirut_dataset = windowed_dataset_single(beirut_values, window_size, batch_size)

# Pass the windowed dataset to the model for inference
predictions = model.predict(beirut_dataset)

# Unwrap the windows
corrected_values = predictions.flatten()

# Inverse transform the corrected values
corrected_values = scaler.inverse_transform(corrected_values.reshape(-1, 1)).flatten()

# corrected_values = scaler.inverse_transform(corrected_values.reshape(-1, 2)).flatten()
print(len(corrected_values))
print(len(beirut_df))

# Save the outputs to 'beirut-daily-corrected.csv'
beirut_df = beirut_df[:len(corrected_values)]
beirut_df['value'] = corrected_values
beirut_df.to_csv('data/beirut-hourly-corrected.csv', index=False)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step
# 221024
# 221039
# /home/edargham/anaconda3/envs/thesis/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
# Save scaler to disk
import joblib
joblib.dump(scaler, 'corrector-ae.scaler.joblib')
# Out:
# ['corrector-ae.scaler.joblib']
